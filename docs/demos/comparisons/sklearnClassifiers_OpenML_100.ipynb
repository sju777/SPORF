# %% [markdown]
# ### This notebook loads in the OpenML 100 suite and classifies each dataset using the sklearn RandomForest classifier. The task IDs, accuracies, and runtimes of each dataset are compiled into .txt files for later analysis.

# %% [markdown]
# # Load in dataset

# %%
import openml
import sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from datetime import datetime

import warnings
warnings.filterwarnings('ignore')

benchmark_suite = openml.study.get_suite('OpenML100')  # obtain the benchmark suite

# %% [markdown]
# # RandomForestClassifier

# %%
# build a scikit-learn classifier
clf = sklearn.pipeline.make_pipeline(sklearn.preprocessing.Imputer(),
                                     sklearn.ensemble.RandomForestClassifier())

for task_id in benchmark_suite.tasks:  # iterate over all tasks
    try:
        f = open("sklearnRF_accuracies_100.txt","a")
        startTime = datetime.now()
        task = openml.tasks.get_task(task_id) # download the OpenML task
        openml.config.apikey = 'c9ea8896542dd998ea42685f14e2bc14'  # set the OpenML Api Key
        run = openml.runs.run_model_on_task(clf, task) # run classifier on splits (requires API key)
        score = run.get_metric_fn(sklearn.metrics.accuracy_score) # print accuracy score
        print('Data set: %s; Accuracy: %0.2f' % (task.get_dataset().name,score.mean()))
        print('Time: '+ str(datetime.now() - startTime))
        f.write('%i,%s,%0.4f,%s,\n' % (task_id,task.get_dataset().name,score.mean(),str(datetime.now() - startTime)))
        f.close()
    except:
        print('Error in' + str(task_id))
# Out:
# Data set: kr-vs-kp; Accuracy: 0.99
# Time: 0:00:01.596959
# Data set: letter; Accuracy: 0.94
# Time: 0:00:02.926510
# Data set: balance-scale; Accuracy: 0.82
# Time: 0:00:00.759715
# Data set: mfeat-factors; Accuracy: 0.95
# Time: 0:00:02.035574
# Data set: mfeat-fourier; Accuracy: 0.80
# Time: 0:00:01.658692
# Data set: breast-w; Accuracy: 0.96
# Time: 0:00:00.716054
# Data set: mfeat-karhunen; Accuracy: 0.91
# Time: 0:00:01.613347
# Data set: mfeat-morphological; Accuracy: 0.69
# Time: 0:00:00.823982
# Data set: mfeat-pixel; Accuracy: 0.96
# Time: 0:00:05.806789
# Data set: car; Accuracy: 0.97
# Time: 0:00:00.856283
# Data set: mfeat-zernike; Accuracy: 0.75
# Time: 0:00:01.507111
# Data set: cmc; Accuracy: 0.50
# Time: 0:00:00.963083
# Data set: mushroom; Accuracy: 1.00
# Time: 0:00:01.388118
# Data set: optdigits; Accuracy: 0.97
# Time: 0:00:01.575346
# Data set: credit-approval; Accuracy: 0.87
# Time: 0:00:00.927174
# Data set: credit-g; Accuracy: 0.75
# Time: 0:00:01.032303
# Data set: pendigits; Accuracy: 0.99
# Time: 0:00:01.988456
# Data set: segment; Accuracy: 0.97
# Time: 0:00:00.950807
# Data set: diabetes; Accuracy: 0.74
# Time: 0:00:00.755148
# Data set: soybean; Accuracy: 0.94
# Time: 0:00:01.461881
# Data set: spambase; Accuracy: 0.94
# Time: 0:00:01.400333
# Data set: splice; Accuracy: 0.93
# Time: 0:00:02.536345
# Data set: tic-tac-toe; Accuracy: 0.94
# Time: 0:00:00.899758
# Data set: vehicle; Accuracy: 0.73
# Time: 0:00:00.808491
# Data set: waveform-5000; Accuracy: 0.81
# Time: 0:00:02.268954
# Data set: electricity; Accuracy: 0.90
# Time: 0:00:06.299394
# Data set: satimage; Accuracy: 0.90
# Time: 0:00:01.856719
# Data set: eucalyptus; Accuracy: 0.63
# Time: 0:00:00.902969
# Data set: sick; Accuracy: 0.98
# Time: 0:00:01.349879
# Data set: vowel; Accuracy: 0.93
# Time: 0:00:00.899040
# Data set: isolet; Accuracy: 0.90
# Time: 0:00:17.182821
# Data set: scene; Accuracy: 0.89
# Time: 0:00:04.148322
# Data set: monks-problems-1; Accuracy: 0.98
# Time: 0:00:00.860737
# Data set: monks-problems-2; Accuracy: 0.92
# Time: 0:00:00.874514
# Data set: monks-problems-3; Accuracy: 0.97
# Time: 0:00:00.960986
# Data set: JapaneseVowels; Accuracy: 0.95
# Time: 0:00:03.011216
# Data set: synthetic_control; Accuracy: 0.98
# Time: 0:00:01.169704
# Data set: irish; Accuracy: 1.00
# Time: 0:00:00.808407
# Data set: analcatdata_authorship; Accuracy: 0.98
# Time: 0:00:00.980028
# Data set: analcatdata_dmft; Accuracy: 0.19
# Time: 0:00:00.846594
# Data set: profb; Accuracy: 0.65
# Time: 0:00:00.931489
# Data set: collins; Accuracy: 0.78
# Time: 0:00:01.095788
# Data set: mnist_784; Accuracy: 0.95
# Time: 0:01:50.143571
# Data set: sylva_agnostic; Accuracy: 0.99
# Time: 0:00:07.476689
# Data set: gina_agnostic; Accuracy: 0.91
# Time: 0:00:07.833005
# Data set: ada_agnostic; Accuracy: 0.83
# Time: 0:00:01.580936
# Data set: mozilla4; Accuracy: 0.95
# Time: 0:00:02.735747
# Data set: pc4; Accuracy: 0.90
# Time: 0:00:01.156488
# Data set: pc3; Accuracy: 0.90
# Time: 0:00:01.100673
# Data set: jm1; Accuracy: 0.81
# Time: 0:00:02.946113
# Data set: kc2; Accuracy: 0.82
# Time: 0:00:00.845618
# Data set: kc1; Accuracy: 0.85
# Time: 0:00:01.004531
# Data set: pc1; Accuracy: 0.93
# Time: 0:00:00.939768
# Data set: KDDCup09_churn; Accuracy: 0.93
# Time: 0:01:00.752943
# Data set: KDDCup09_upselling; Accuracy: 0.94
# Time: 0:01:00.063714
# Data set: MagicTelescope; Accuracy: 0.87
# Time: 0:00:08.434843
# Data set: adult; Accuracy: 0.85
# Time: 0:00:07.782104
# Data set: wilt; Accuracy: 0.98
# Time: 0:00:01.457366
# Data set: wdbc; Accuracy: 0.95
# Time: 0:00:01.030093
# Data set: micro-mass; Accuracy: 0.83
# Time: 0:00:05.359356
# Data set: phoneme; Accuracy: 0.89
# Time: 0:00:01.871378
# Data set: one-hundred-plants-margin; Accuracy: 0.66
# Time: 0:00:02.184180
# Data set: one-hundred-plants-shape; Accuracy: 0.56
# Time: 0:00:03.453610
# Data set: one-hundred-plants-texture; Accuracy: 0.70
# Time: 0:00:02.483611
# Data set: qsar-biodeg; Accuracy: 0.85
# Time: 0:00:01.251784
# Data set: wall-robot-navigation; Accuracy: 0.99
# Time: 0:00:02.057972
# Data set: semeion; Accuracy: 0.89
# Time: 0:00:02.035258
# Data set: steel-plates-fault; Accuracy: 0.98
# Time: 0:00:01.366759
# Data set: tamilnadu-electricity; Accuracy: 0.99
# Time: 0:00:08.689321
# Data set: hill-valley; Accuracy: 0.58
# Time: 0:00:02.157889
# Data set: ilpd; Accuracy: 0.71
# Time: 0:00:00.855096
# Data set: madelon; Accuracy: 0.61
# Time: 0:00:05.505322
# Data set: nomao; Accuracy: 0.97
# Time: 0:00:12.207818
# Data set: ozone-level-8hr; Accuracy: 0.94
# Time: 0:00:01.576187
# Data set: cardiotocography; Accuracy: 1.00
# Time: 0:00:01.032336
# Data set: climate-model-simulation-crashes; Accuracy: 0.90
# Time: 0:00:00.861681
# Data set: cnae-9; Accuracy: 0.91
# Time: 0:00:04.154328
# Data set: eeg-eye-state; Accuracy: 0.90
# Time: 0:00:03.715169
# Data set: first-order-theorem-proving; Accuracy: 0.60
# Time: 0:00:03.212471
# Data set: gas-drift; Accuracy: 0.99
# Time: 0:00:13.537334
# Data set: banknote-authentication; Accuracy: 0.99
# Time: 0:00:00.852664
# Data set: blood-transfusion-service-center; Accuracy: 0.76
# Time: 0:00:00.798851
# Data set: artificial-characters; Accuracy: 0.92
# Time: 0:00:01.868680
# Data set: bank-marketing; Accuracy: 0.90
# Time: 0:00:07.397311
# Data set: Bioresponse; Accuracy: 0.77
# Time: 0:00:12.235568
# Data set: cjs; Accuracy: 0.75
# Time: 0:00:01.313945
# Data set: cylinder-bands; Accuracy: 0.75
# Time: 0:00:01.515134
# Data set: GesturePhaseSegmentationProcessed; Accuracy: 0.60
# Time: 0:00:05.497064
# Data set: har; Accuracy: 0.97
# Time: 0:00:23.468174
# Error in34536
# Data set: PhishingWebsites; Accuracy: 0.97
# Time: 0:00:02.805642
# Data set: MiceProtein; Accuracy: 1.00
# Time: 0:00:02.160069
# Data set: Amazon_employee_access; Accuracy: 0.95
# Time: 0:00:08.106872
# Data set: dresses-sales; Accuracy: 0.58
# Time: 0:00:01.264443
# Data set: LED-display-domain-7digit; Accuracy: 0.71
# Time: 0:00:00.797816
# Data set: texture; Accuracy: 0.97
# Time: 0:00:03.017079
# Data set: Australian; Accuracy: 0.86
# Time: 0:00:01.322332
# Data set: connect-4; Accuracy: 0.79
# Time: 0:00:12.864994
# Data set: higgs; Accuracy: 0.68
# Time: 0:01:01.654284
# Data set: SpeedDating; Accuracy: 0.85
# Time: 0:00:05.915070
