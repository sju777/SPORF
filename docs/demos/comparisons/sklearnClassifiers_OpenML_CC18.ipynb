# %% [markdown]
# ### This notebook loads in the OpenML CC18 suite and classifies each dataset using the sklearn RandomForest classifier. The task IDs, accuracies, and runtimes of each dataset are compiled into .txt files for later analysis.

# %% [markdown]
# # Load in dataset

# %%
import openml
import sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from datetime import datetime

import warnings
warnings.filterwarnings('ignore')

benchmark_suite = openml.study.get_suite('OpenML-CC18')  # obtain the benchmark suite

# %% [markdown]
# # RandomForestClassifier

# %%
# build a scikit-learn classifier
clf = sklearn.pipeline.make_pipeline(sklearn.preprocessing.Imputer(),
                                     sklearn.ensemble.RandomForestClassifier())

for task_id in benchmark_suite.tasks:  # iterate over all tasks
    f = open("sklearnRF_accuracies_CC-18.txt","a")
    startTime = datetime.now()
    task = openml.tasks.get_task(task_id) # download the OpenML task
    openml.config.apikey = 'c9ea8896542dd998ea42685f14e2bc14'  # set the OpenML Api Key
    run = openml.runs.run_model_on_task(clf, task) # run classifier on splits (requires API key)
    score = run.get_metric_fn(sklearn.metrics.accuracy_score) # print accuracy score
    print('Data set: %s; Accuracy: %0.4f' % (task.get_dataset().name,score.mean()))
    print('Time: '+ str(datetime.now() - startTime))
    f.write('%i,%s,%0.4f,%s,\n' % (task_id,task.get_dataset().name,score.mean(),str(datetime.now() - startTime)))
    f.close()
# Out:
# Data set: kr-vs-kp; Accuracy: 0.9828
# Time: 0:00:01.648604
# Data set: letter; Accuracy: 0.9401
# Time: 0:00:03.120219
# Data set: balance-scale; Accuracy: 0.8271
# Time: 0:00:00.717325
# Data set: mfeat-factors; Accuracy: 0.9460
# Time: 0:00:01.910577
# Data set: mfeat-fourier; Accuracy: 0.8040
# Time: 0:00:01.683703
# Data set: breast-w; Accuracy: 0.9613
# Time: 0:00:00.714478
# Data set: mfeat-karhunen; Accuracy: 0.9065
# Time: 0:00:01.603372
# Data set: mfeat-morphological; Accuracy: 0.6950
# Time: 0:00:00.854322
# Data set: mfeat-zernike; Accuracy: 0.7595
# Time: 0:00:01.463599
# Data set: cmc; Accuracy: 0.5146
# Time: 0:00:00.948737
# Data set: optdigits; Accuracy: 0.9648
# Time: 0:00:01.647045
# Data set: credit-approval; Accuracy: 0.8652
# Time: 0:00:00.920062
# Data set: credit-g; Accuracy: 0.7330
# Time: 0:00:01.052426
# Data set: pendigits; Accuracy: 0.9868
# Time: 0:00:01.884745
# Data set: diabetes; Accuracy: 0.7487
# Time: 0:00:00.731393
# Data set: spambase; Accuracy: 0.9470
# Time: 0:00:01.357894
# Data set: splice; Accuracy: 0.9270
# Time: 0:00:02.417349
# Data set: tic-tac-toe; Accuracy: 0.9301
# Time: 0:00:00.864605
# Data set: vehicle; Accuracy: 0.7577
# Time: 0:00:00.776215
# Data set: electricity; Accuracy: 0.8970
# Time: 0:00:05.991848
# Data set: satimage; Accuracy: 0.9005
# Time: 0:00:01.773534
# Data set: eucalyptus; Accuracy: 0.6316
# Time: 0:00:00.874467
# Data set: sick; Accuracy: 0.9838
# Time: 0:00:01.414099
# Data set: vowel; Accuracy: 0.9222
# Time: 0:00:00.866592
# Data set: isolet; Accuracy: 0.9042
# Time: 0:00:15.993359
# Data set: analcatdata_authorship; Accuracy: 0.9798
# Time: 0:00:00.949043
# Data set: analcatdata_dmft; Accuracy: 0.2070
# Time: 0:00:00.789361
# Data set: mnist_784; Accuracy: 0.9484
# Time: 0:01:39.651278
# Data set: pc4; Accuracy: 0.8923
# Time: 0:00:01.174488
# Data set: pc3; Accuracy: 0.8944
# Time: 0:00:01.144073
# Data set: jm1; Accuracy: 0.8109
# Time: 0:00:03.202405
# Data set: kc2; Accuracy: 0.8333
# Time: 0:00:00.864542
# Data set: kc1; Accuracy: 0.8483
# Time: 0:00:01.136801
# Data set: pc1; Accuracy: 0.9278
# Time: 0:00:00.976331
# Data set: adult; Accuracy: 0.8455
# Time: 0:00:08.215057
# Data set: Bioresponse; Accuracy: 0.7795
# Time: 0:00:13.391732
# Data set: wdbc; Accuracy: 0.9596
# Time: 0:00:00.922982
# Data set: phoneme; Accuracy: 0.8975
# Time: 0:00:01.733231
# Data set: qsar-biodeg; Accuracy: 0.8531
# Time: 0:00:01.172537
# Data set: wall-robot-navigation; Accuracy: 0.9905
# Time: 0:00:02.092046
# Data set: semeion; Accuracy: 0.8763
# Time: 0:00:01.963026
# Data set: ilpd; Accuracy: 0.7120
# Time: 0:00:00.892872
# Data set: madelon; Accuracy: 0.6231
# Time: 0:00:06.201519
# Data set: nomao; Accuracy: 0.9659
# Time: 0:00:13.282856
# Data set: ozone-level-8hr; Accuracy: 0.9400
# Time: 0:00:01.721019
# Data set: cnae-9; Accuracy: 0.9037
# Time: 0:00:04.329266
# Data set: first-order-theorem-proving; Accuracy: 0.6077
# Time: 0:00:03.487241
# Data set: banknote-authentication; Accuracy: 0.9898
# Time: 0:00:00.842985
# Data set: blood-transfusion-service-center; Accuracy: 0.7500
# Time: 0:00:00.814537
# Data set: PhishingWebsites; Accuracy: 0.9720
# Time: 0:00:02.353831
# Data set: cylinder-bands; Accuracy: 0.8037
# Time: 0:00:01.512998
# Data set: bank-marketing; Accuracy: 0.8986
# Time: 0:00:07.555762
# Data set: GesturePhaseSegmentationProcessed; Accuracy: 0.6063
# Time: 0:00:06.121316
# Data set: har; Accuracy: 0.9655
# Time: 0:00:26.208915
# Data set: dresses-sales; Accuracy: 0.5360
# Time: 0:00:01.199061
# Data set: texture; Accuracy: 0.9682
# Time: 0:00:02.837738
# Data set: connect-4; Accuracy: 0.7901
# Time: 0:00:12.570310
# Data set: MiceProtein; Accuracy: 0.9602
# Time: 0:00:01.648306
# Data set: steel-plates-fault; Accuracy: 0.7517
# Time: 0:00:01.307830
# Data set: climate-model-simulation-crashes; Accuracy: 0.9222
# Time: 0:00:00.851279
# Data set: wilt; Accuracy: 0.9818
# Time: 0:00:01.201657
# Data set: car; Accuracy: 0.9740
# Time: 0:00:00.994299
# Data set: segment; Accuracy: 0.9338
# Time: 0:00:01.170855
# Data set: mfeat-pixel; Accuracy: 0.9605
# Time: 0:00:01.748731
# Data set: Fashion-MNIST; Accuracy: 0.8607
# Time: 0:02:48.456339
# Data set: jungle_chess_2pcs_raw_endgame_complete; Accuracy: 0.7778
# Time: 0:00:04.524253
# Data set: numerai28.6; Accuracy: 0.5019
# Time: 0:00:53.186302
# Data set: Devnagari-Script; Accuracy: 0.7987
# Time: 0:03:37.614029
# Data set: CIFAR_10; Accuracy: 0.3560
# Time: 0:07:05.323230
# Data set: Internet-Advertisements; Accuracy: 0.9793
# Time: 0:00:44.133611
# Data set: dna; Accuracy: 0.9168
# Time: 0:00:05.775044
# Data set: churn; Accuracy: 0.9480
# Time: 0:00:01.720152
